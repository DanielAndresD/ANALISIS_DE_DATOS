# %%
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
rutaArchivo='examen1.xlsx' #Archivo a trabajar
hoja='examen1' #hoja del archivo

data= pd.read_excel(rutaArchivo,sheet_name=hoja)
#Eliminar campo de conteo
data=data.drop(data.columns[[0,1]],axis=1)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 517 entries, 0 to 516
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   inicio      517 non-null    object
#  1   final       517 non-null    object
#  2   nota        517 non-null    float64
#  3   p1          517 non-null    float64
#  4   p2          517 non-null    float64
#  5   p3          517 non-null    float64
#  6   p4          517 non-null    float64
#  7   p5          517 non-null    float64
#  8   p6          517 non-null    object
#  9   p7          517 non-null    float64
#  10  p8          517 non-null    float64
#  11  p9          517 non-null    float64
#  12  p10         517 non-null    float64
#  13  grupo       517 non-null    int64
#  14  profesor    517 non-null    object
#  15  jornada     517 non-null    object
#  16  diferencia  517 non-null    object
#  17  delta       517 non-null    float64
# ...

# %% [markdown]
# Agrupar la BD por Profesor e indicar jornada, nota promedio y cantidad de estudiantes

# %%
filtro1=data.groupby(['profesor','jornada']).agg(notaProm=('nota','mean'),numEst=('nota','count'))
filtro1
# Out:
#                                               notaProm  numEst
# profesor                             jornada
# Alfonso Peña Suarez                  Día      2.652174      23
# Claudia Angelica Ben-Amy Paez        Noche    2.192308      13
# Dora Janeth Alfonso Combita          Día      1.977778      45
# Edward Fernando Hurtado Cuesto       Noche    0.833333       6
# Ernesto Neiva  Restrepo              Noche    1.785714      14
# German David Sosa Ramirez            Día      2.000000      17
# Gloria Milena Fernandez Nieto        Noche    1.692308      13
# Huvert Hurtado Caicedo               Noche    1.897436      39
# Javier Augusto Rios Suarez           Noche    2.458333      12
# John Jairo Londoño Perez             Día      1.736842      38
#                                      Noche    3.000000       1
# Jorge Antonio Blanco Velandia        Noche    1.937500      16
# Jorge Eliecer Ariza Calderon         Noche    1.461538      13
# ...
